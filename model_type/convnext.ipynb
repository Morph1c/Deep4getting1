# %%
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)

# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

#for gan...

from tqdm import tqdm

import copy
def add_noise(cop):
    '''Add random noise to an image'''
    imagee = copy.copy(cop)
    VARIABILITY = 0.03
    deviation = VARIABILITY
    noise = np.random.normal(0, deviation, imagee.shape)
    imagee += noise
    # np.clip(img, 0., 255.)
    return imagee
# Out:
# 2.13.0

# %%
os.getcwd()
# Out:
# '/kaggle/working'

# %%
# Load images from the 'items/' folder
temp = np.load('/kaggle/input/plants-data/public_data.npz', allow_pickle = True)
img = temp["data"]
label = temp["labels"]
  # Normalize image pixel values to a float range [0, 1]
img = (img / 255).astype(np.float32)

# set 0,1 label
for i in range(len(label)):
    if(label[i] == 'healthy'):
        label[i] = 0
    else:
        label[i] = 1

# cleaning images from trol and shrek
ref_img = img[58]
ref_img2 = img[2150]
c = 0
c2 = 0
rm_indexes = []
rm2_indexes = []
for i in range(0, len(img)):
    deviation = np.mean(np.abs(ref_img - img[i]))
    deviation2 = np.mean(np.abs(ref_img2 - img[i]))
    if(deviation == 0.0):
        #print(i)
        c += 1
        rm_indexes.append(i)
    elif(deviation2 == 0.0):
        c2 += 1
        rm2_indexes.append(i)

clean_img = np.delete(img, rm_indexes + rm2_indexes, axis=0)
clean_label = np.delete(label, rm_indexes + rm2_indexes, axis=0)


#DATA AUGMENTATION TO BALANCE CLASSES
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# Create an instance of ImageDataGenerator
datagen = ImageDataGenerator(
#     rotation_range=40,
#     shear_range=0.2,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     vertical_flip=True,
    # brightness_range=[0, 0.7],
    preprocessing_function=add_noise,
    fill_mode='nearest'
)

# Reshape the numpy array to fit the requirements of the flow method
x = clean_img[clean_label == 1]  # Replace 'your_numpy_array' with your actual numpy array

# Create a generator to augment the images
augmented_images = []
for x_batch in datagen.flow(x, batch_size=1, seed=42, shuffle=False):
    augmented_images.append(x_batch[0])
    if len(augmented_images) >= 1198:
        break

# Convert the list of augmented images to a numpy array
augmented_images_array = np.array(augmented_images)

clean_img = np.append(clean_img, augmented_images_array, axis = 0)
clean_label = np.append(clean_label, np.ones(1198))
print(clean_img.shape)
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


# Concatenate 'animals' and 'items' arrays along axis 0
X = clean_img
# Create labels: 1 for 'animals', 0 for 'items'
y = clean_label

y = tfk.utils.to_categorical(y, 2) #one hot encodi

# Split data into train_val and test sets
#X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=1000, stratify=np.argmax(y,axis=1))
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=1000, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
#X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=1000, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
#print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Explain
# def getSamplesFromDataGen(resultData):
#     x = resultData.next() #fetch the first batch
#     a = x[0] # train data
#     b = x[1] # train label
#     for i in range(0,5):
#         plt.imshow(a[i])
#         plt.title(b[i])
#         plt.show()
BATCH_SIZE = 32

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# # train generator with augmentation
train_image_gen  = ImageDataGenerator(rotation_range=40, #maybe better not to rotate??
                                      width_shift_range=0.2,
                                      height_shift_range=0.2,
                                      zoom_range=[0.5,1.5],
                                      shear_range=0.2,
                                      vertical_flip=True,
                                      horizontal_flip=True,
                                      fill_mode='nearest',
                                      validation_split = 0.15
                                      )


# validation generator without augmentation
# validation_image_gen = ImageDataGenerator(validation_split = 0.15, 
#                                           )

train_dataset = train_image_gen.flow(x = X_train, y = y_train, seed = 42,
                                     batch_size = BATCH_SIZE)
validation_dataset = ImageDataGenerator().flow(X_val, y_val)
# Out:
# (6202, 96, 96, 3)
# X_train shape: (5202, 96, 96, 3), y_train shape: (5202, 2)
# X_val shape: (1000, 96, 96, 3), y_val shape: (1000, 2)

# %%
import time
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
class LR_ASK(tf.keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch, dwell=True, factor=.75): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.lowest_aloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        self.plist=[]
        self.alist=[]
        self.dwell= dwell
        self.factor=factor
        
    def get_list(self): # define a function to return the list of % validation change
        return self.plist, self.alist
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            msg =f'Training will proceed until epoch {ask_epoch} then you will be asked to' 
            print(msg )
            msg='enter H to halt training or enter an integer for how many more epochs to run then be asked again'
            print(msg)
            if self.dwell:
                msg='learning rate will be automatically adjusted during training'
                print(msg, (0,255,0))
        self.start_time= time.time() # set the time at which training started
       
    def on_train_end(self, logs=None):   # runs at the end of training  
        msg=f'loading model with weights from epoch {self.best_epoch}'
        print(msg)
        model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        vloss=logs.get('val_loss')  # get the validation loss for this epoch
        aloss=logs.get('loss')
        if epoch >0:
            deltav = self.lowest_vloss- vloss 
            pimprov=(deltav/self.lowest_vloss) * 100 
            self.plist.append(pimprov)
            deltaa=self.lowest_aloss-aloss
            aimprov=(deltaa/self.lowest_aloss) * 100
            self.alist.append(aimprov)
        else:
            pimprov=0.0 
            aimprov=0.0
        if vloss< self.lowest_vloss:
            self.lowest_vloss=vloss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1            
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights'
            print(msg) # green foreground
        else: # validation loss increased
            pimprov=abs(pimprov)
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights'
            print(msg) # yellow foreground
            if self.dwell: # if dwell is True when the validation loss increases the learning rate is automatically reduced and model weights are set to best weights
                lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                new_lr=lr * self.factor
                msg=f'learning rate was automatically adjusted from {lr:8.6f} to {new_lr:8.6f}, model weights set to best weights'
                print(msg) # cyan foreground
                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                model.set_weights(self.best_weights) # set the weights of the model to the best weights      
                
        if aloss< self.lowest_aloss:
            self.lowest_aloss=aloss        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                msg='\n Enter H to end training or  an integer for the number of additional epochs to run then ask again'
                print(msg) # cyan foreground
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    msg=f'you entered {ans},  Training halted on epoch {epoch+1} due to user input\n'
                    print(msg)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        msg=f'you entered {ans} Training will continue to epoch {self.ask_epoch}'
                        print(msg) # cyan foreground
                        if self.dwell==False:
                            lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                            msg=f'current LR is  {lr:8.6f}  hit enter to keep  this LR or enter a new LR'
                            print(msg) # cyan foreground
                            ans=input(' ')
                            if ans =='':
                                msg=f'keeping current LR of {lr:7.5f}'
                                print(msg) # cyan foreground
                            else:
                                new_lr=float(ans)
                                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                                msg=f' changing LR to {ans}'
                                print(msg) # cyan foreground

# %%
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model

def make_model(img_size = [96, 96], lr = 0.01, mod_num=3):
    img_shape=(img_size[0], img_size[1], 3)
    if mod_num == 0:
        base_model=tf.keras.applications.efficientnet.EfficientNetB0(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B0 model'
    elif mod_num == 3:
        base_model=tf.keras.applications.efficientnet.EfficientNetB3(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B3 model'
    elif mod_num == 5:
        base_model=tf.keras.applications.efficientnet.EfficientNetB5(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B5 model'
    elif mod_num == 7: # create large ConvNext
        base_model=tf.keras.applications.ConvNeXtXLarge(model_name = 'convnext_xlarge', include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created ConvNeXtXLarge model'
    else:
        base_model=tf.keras.applications.efficientnet.EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B7 model'
    base_model.trainable=False # TRANSFER-LEARNING
    x=base_model.output
    x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                  bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
    x=Dropout(rate=.4, seed=123)(x)
    output=Dense(2, activation='softmax')(x)


    model=Model(inputs=base_model.input, outputs=output)
    model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
    msg=msg + f' with initial learning rate set to {lr}'
    print(msg)
    return model

def make_convnext(img_size = [96, 96], lr = 0.01):
    img_shape=(img_size[0], img_size[1], 3)
    base_model=tf.keras.applications.ConvNeXtXLarge(model_name = 'convnext_xlarge', include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
    msg='Created ConvNeXtXLarge model'
    base_model.trainable=False # TRANSFER-LEARNING
    x=base_model.output
    
    x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                  bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
    x=Dropout(rate=.4, seed=123)(x)
    output=Dense(2, activation='softmax')(x)


    model=Model(inputs=base_model.input, outputs=output)
    model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
    msg=msg + f' with initial learning rate set to {lr}'
    print(msg)
    return model

lr=.001
#model=make_model(lr = lr, mod_num = 7) # using B3 model by default
model=make_convnext(lr = lr)
model.summary()
# Out:
# Created ConvNeXtXLarge model with initial learning rate set to 0.001
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  convnext_xlarge_prestem_no  (None, 96, 96, 3)            0         ['input_5[0][0]']
#  rmalization (Normalization
#  )
#
#  convnext_xlarge_stem (Sequ  (None, 24, 24, 256)          13056     ['convnext_xlarge_prestem_norm
#  ential)                                                            alization[0][0]']
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          12800     ['convnext_xlarge_stem[0][0]']
#  ock_0_depthwise_conv (Conv
#  2D)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          512       ['convnext_xlarge_stage_0_bloc
#  ock_0_layernorm (LayerNorm                                         k_0_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 1024)         263168    ['convnext_xlarge_stage_0_bloc
#  ock_0_pointwise_conv_1 (De                                         k_0_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 1024)         0         ['convnext_xlarge_stage_0_bloc
#  ock_0_gelu (Activation)                                            k_0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          262400    ['convnext_xlarge_stage_0_bloc
#  ock_0_pointwise_conv_2 (De                                         k_0_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          256       ['convnext_xlarge_stage_0_bloc
#  ock_0_layer_scale (LayerSc                                         k_0_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          0         ['convnext_xlarge_stage_0_bloc
#  ock_0_identity (Activation                                         k_0_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_36 (T  (None, 24, 24, 256)          0         ['convnext_xlarge_stem[0][0]',
#  FOpLambda)                                                          'convnext_xlarge_stage_0_bloc
#                                                                     k_0_identity[0][0]']
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          12800     ['tf.__operators__.add_36[0][0
#  ock_1_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          512       ['convnext_xlarge_stage_0_bloc
#  ock_1_layernorm (LayerNorm                                         k_1_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 1024)         263168    ['convnext_xlarge_stage_0_bloc
#  ock_1_pointwise_conv_1 (De                                         k_1_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 1024)         0         ['convnext_xlarge_stage_0_bloc
#  ock_1_gelu (Activation)                                            k_1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          262400    ['convnext_xlarge_stage_0_bloc
#  ock_1_pointwise_conv_2 (De                                         k_1_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          256       ['convnext_xlarge_stage_0_bloc
#  ock_1_layer_scale (LayerSc                                         k_1_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          0         ['convnext_xlarge_stage_0_bloc
#  ock_1_identity (Activation                                         k_1_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_37 (T  (None, 24, 24, 256)          0         ['tf.__operators__.add_36[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_0_bloc
#                                                                     k_1_identity[0][0]']
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          12800     ['tf.__operators__.add_37[0][0
#  ock_2_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          512       ['convnext_xlarge_stage_0_bloc
#  ock_2_layernorm (LayerNorm                                         k_2_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 1024)         263168    ['convnext_xlarge_stage_0_bloc
#  ock_2_pointwise_conv_1 (De                                         k_2_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 1024)         0         ['convnext_xlarge_stage_0_bloc
#  ock_2_gelu (Activation)                                            k_2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          262400    ['convnext_xlarge_stage_0_bloc
#  ock_2_pointwise_conv_2 (De                                         k_2_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          256       ['convnext_xlarge_stage_0_bloc
#  ock_2_layer_scale (LayerSc                                         k_2_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_0_bl  (None, 24, 24, 256)          0         ['convnext_xlarge_stage_0_bloc
#  ock_2_identity (Activation                                         k_2_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_38 (T  (None, 24, 24, 256)          0         ['tf.__operators__.add_37[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_0_bloc
#                                                                     k_2_identity[0][0]']
#
#  convnext_xlarge_downsampli  (None, 12, 12, 512)          525312    ['tf.__operators__.add_38[0][0
#  ng_block_0 (Sequential)                                            ]']
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          25600     ['convnext_xlarge_downsampling
#  ock_0_depthwise_conv (Conv                                         _block_0[0][0]']
#  2D)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          1024      ['convnext_xlarge_stage_1_bloc
#  ock_0_layernorm (LayerNorm                                         k_0_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 2048)         1050624   ['convnext_xlarge_stage_1_bloc
#  ock_0_pointwise_conv_1 (De                                         k_0_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 2048)         0         ['convnext_xlarge_stage_1_bloc
#  ock_0_gelu (Activation)                                            k_0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          1049088   ['convnext_xlarge_stage_1_bloc
#  ock_0_pointwise_conv_2 (De                                         k_0_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          512       ['convnext_xlarge_stage_1_bloc
#  ock_0_layer_scale (LayerSc                                         k_0_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          0         ['convnext_xlarge_stage_1_bloc
#  ock_0_identity (Activation                                         k_0_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_39 (T  (None, 12, 12, 512)          0         ['convnext_xlarge_downsampling
#  FOpLambda)                                                         _block_0[0][0]',
#                                                                      'convnext_xlarge_stage_1_bloc
#                                                                     k_0_identity[0][0]']
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          25600     ['tf.__operators__.add_39[0][0
#  ock_1_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          1024      ['convnext_xlarge_stage_1_bloc
#  ock_1_layernorm (LayerNorm                                         k_1_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 2048)         1050624   ['convnext_xlarge_stage_1_bloc
#  ock_1_pointwise_conv_1 (De                                         k_1_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 2048)         0         ['convnext_xlarge_stage_1_bloc
#  ock_1_gelu (Activation)                                            k_1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          1049088   ['convnext_xlarge_stage_1_bloc
#  ock_1_pointwise_conv_2 (De                                         k_1_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          512       ['convnext_xlarge_stage_1_bloc
#  ock_1_layer_scale (LayerSc                                         k_1_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          0         ['convnext_xlarge_stage_1_bloc
#  ock_1_identity (Activation                                         k_1_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_40 (T  (None, 12, 12, 512)          0         ['tf.__operators__.add_39[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_1_bloc
#                                                                     k_1_identity[0][0]']
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          25600     ['tf.__operators__.add_40[0][0
#  ock_2_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          1024      ['convnext_xlarge_stage_1_bloc
#  ock_2_layernorm (LayerNorm                                         k_2_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 2048)         1050624   ['convnext_xlarge_stage_1_bloc
#  ock_2_pointwise_conv_1 (De                                         k_2_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 2048)         0         ['convnext_xlarge_stage_1_bloc
#  ock_2_gelu (Activation)                                            k_2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          1049088   ['convnext_xlarge_stage_1_bloc
#  ock_2_pointwise_conv_2 (De                                         k_2_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          512       ['convnext_xlarge_stage_1_bloc
#  ock_2_layer_scale (LayerSc                                         k_2_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_1_bl  (None, 12, 12, 512)          0         ['convnext_xlarge_stage_1_bloc
#  ock_2_identity (Activation                                         k_2_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_41 (T  (None, 12, 12, 512)          0         ['tf.__operators__.add_40[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_1_bloc
#                                                                     k_2_identity[0][0]']
#
#  convnext_xlarge_downsampli  (None, 6, 6, 1024)           2099200   ['tf.__operators__.add_41[0][0
#  ng_block_1 (Sequential)                                            ]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['convnext_xlarge_downsampling
#  ock_0_depthwise_conv (Conv                                         _block_1[0][0]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_0_layernorm (LayerNorm                                         k_0_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_0_pointwise_conv_1 (De                                         k_0_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_0_gelu (Activation)                                            k_0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_0_pointwise_conv_2 (De                                         k_0_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_0_layer_scale (LayerSc                                         k_0_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_0_identity (Activation                                         k_0_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_42 (T  (None, 6, 6, 1024)           0         ['convnext_xlarge_downsampling
#  FOpLambda)                                                         _block_1[0][0]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_0_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_42[0][0
#  ock_1_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_1_layernorm (LayerNorm                                         k_1_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_1_pointwise_conv_1 (De                                         k_1_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_1_gelu (Activation)                                            k_1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_1_pointwise_conv_2 (De                                         k_1_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_1_layer_scale (LayerSc                                         k_1_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_1_identity (Activation                                         k_1_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_43 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_42[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_1_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_43[0][0
#  ock_2_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_2_layernorm (LayerNorm                                         k_2_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_2_pointwise_conv_1 (De                                         k_2_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_2_gelu (Activation)                                            k_2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_2_pointwise_conv_2 (De                                         k_2_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_2_layer_scale (LayerSc                                         k_2_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_2_identity (Activation                                         k_2_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_44 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_43[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_2_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_44[0][0
#  ock_3_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_3_layernorm (LayerNorm                                         k_3_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_3_pointwise_conv_1 (De                                         k_3_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_3_gelu (Activation)                                            k_3_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_3_pointwise_conv_2 (De                                         k_3_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_3_layer_scale (LayerSc                                         k_3_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_3_identity (Activation                                         k_3_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_45 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_44[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_3_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_45[0][0
#  ock_4_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_4_layernorm (LayerNorm                                         k_4_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_4_pointwise_conv_1 (De                                         k_4_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_4_gelu (Activation)                                            k_4_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_4_pointwise_conv_2 (De                                         k_4_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_4_layer_scale (LayerSc                                         k_4_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_4_identity (Activation                                         k_4_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_46 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_45[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_4_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_46[0][0
#  ock_5_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_5_layernorm (LayerNorm                                         k_5_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_5_pointwise_conv_1 (De                                         k_5_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_5_gelu (Activation)                                            k_5_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_5_pointwise_conv_2 (De                                         k_5_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_5_layer_scale (LayerSc                                         k_5_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_5_identity (Activation                                         k_5_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_47 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_46[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_5_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_47[0][0
#  ock_6_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_6_layernorm (LayerNorm                                         k_6_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_6_pointwise_conv_1 (De                                         k_6_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_6_gelu (Activation)                                            k_6_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_6_pointwise_conv_2 (De                                         k_6_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_6_layer_scale (LayerSc                                         k_6_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_6_identity (Activation                                         k_6_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_48 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_47[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_6_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_48[0][0
#  ock_7_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_7_layernorm (LayerNorm                                         k_7_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_7_pointwise_conv_1 (De                                         k_7_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_7_gelu (Activation)                                            k_7_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_7_pointwise_conv_2 (De                                         k_7_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_7_layer_scale (LayerSc                                         k_7_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_7_identity (Activation                                         k_7_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_49 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_48[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_7_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_49[0][0
#  ock_8_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_8_layernorm (LayerNorm                                         k_8_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_8_pointwise_conv_1 (De                                         k_8_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_8_gelu (Activation)                                            k_8_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_8_pointwise_conv_2 (De                                         k_8_gelu[0][0]']
#  nse)
# ...
#  cale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_25_identity (Activatio                                         k_25_layer_scale[0][0]']
#  n)
#
#  tf.__operators__.add_67 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_66[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_25_identity[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           51200     ['tf.__operators__.add_67[0][0
#  ock_26_depthwise_conv (Con                                         ]']
#  v2D)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           2048      ['convnext_xlarge_stage_2_bloc
#  ock_26_layernorm (LayerNor                                         k_26_depthwise_conv[0][0]']
#  malization)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           4198400   ['convnext_xlarge_stage_2_bloc
#  ock_26_pointwise_conv_1 (D                                         k_26_layernorm[0][0]']
#  ense)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 4096)           0         ['convnext_xlarge_stage_2_bloc
#  ock_26_gelu (Activation)                                           k_26_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           4195328   ['convnext_xlarge_stage_2_bloc
#  ock_26_pointwise_conv_2 (D                                         k_26_gelu[0][0]']
#  ense)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           1024      ['convnext_xlarge_stage_2_bloc
#  ock_26_layer_scale (LayerS                                         k_26_pointwise_conv_2[0][0]']
#  cale)
#
#  convnext_xlarge_stage_2_bl  (None, 6, 6, 1024)           0         ['convnext_xlarge_stage_2_bloc
#  ock_26_identity (Activatio                                         k_26_layer_scale[0][0]']
#  n)
#
#  tf.__operators__.add_68 (T  (None, 6, 6, 1024)           0         ['tf.__operators__.add_67[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_2_bloc
#                                                                     k_26_identity[0][0]']
#
#  convnext_xlarge_downsampli  (None, 3, 3, 2048)           8392704   ['tf.__operators__.add_68[0][0
#  ng_block_2 (Sequential)                                            ]']
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           102400    ['convnext_xlarge_downsampling
#  ock_0_depthwise_conv (Conv                                         _block_2[0][0]']
#  2D)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           4096      ['convnext_xlarge_stage_3_bloc
#  ock_0_layernorm (LayerNorm                                         k_0_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 8192)           1678540   ['convnext_xlarge_stage_3_bloc
#  ock_0_pointwise_conv_1 (De                               8         k_0_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 8192)           0         ['convnext_xlarge_stage_3_bloc
#  ock_0_gelu (Activation)                                            k_0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           1677926   ['convnext_xlarge_stage_3_bloc
#  ock_0_pointwise_conv_2 (De                               4         k_0_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           2048      ['convnext_xlarge_stage_3_bloc
#  ock_0_layer_scale (LayerSc                                         k_0_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           0         ['convnext_xlarge_stage_3_bloc
#  ock_0_identity (Activation                                         k_0_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_69 (T  (None, 3, 3, 2048)           0         ['convnext_xlarge_downsampling
#  FOpLambda)                                                         _block_2[0][0]',
#                                                                      'convnext_xlarge_stage_3_bloc
#                                                                     k_0_identity[0][0]']
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           102400    ['tf.__operators__.add_69[0][0
#  ock_1_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           4096      ['convnext_xlarge_stage_3_bloc
#  ock_1_layernorm (LayerNorm                                         k_1_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 8192)           1678540   ['convnext_xlarge_stage_3_bloc
#  ock_1_pointwise_conv_1 (De                               8         k_1_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 8192)           0         ['convnext_xlarge_stage_3_bloc
#  ock_1_gelu (Activation)                                            k_1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           1677926   ['convnext_xlarge_stage_3_bloc
#  ock_1_pointwise_conv_2 (De                               4         k_1_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           2048      ['convnext_xlarge_stage_3_bloc
#  ock_1_layer_scale (LayerSc                                         k_1_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           0         ['convnext_xlarge_stage_3_bloc
#  ock_1_identity (Activation                                         k_1_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_70 (T  (None, 3, 3, 2048)           0         ['tf.__operators__.add_69[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_3_bloc
#                                                                     k_1_identity[0][0]']
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           102400    ['tf.__operators__.add_70[0][0
#  ock_2_depthwise_conv (Conv                                         ]']
#  2D)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           4096      ['convnext_xlarge_stage_3_bloc
#  ock_2_layernorm (LayerNorm                                         k_2_depthwise_conv[0][0]']
#  alization)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 8192)           1678540   ['convnext_xlarge_stage_3_bloc
#  ock_2_pointwise_conv_1 (De                               8         k_2_layernorm[0][0]']
#  nse)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 8192)           0         ['convnext_xlarge_stage_3_bloc
#  ock_2_gelu (Activation)                                            k_2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           1677926   ['convnext_xlarge_stage_3_bloc
#  ock_2_pointwise_conv_2 (De                               4         k_2_gelu[0][0]']
#  nse)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           2048      ['convnext_xlarge_stage_3_bloc
#  ock_2_layer_scale (LayerSc                                         k_2_pointwise_conv_2[0][0]']
#  ale)
#
#  convnext_xlarge_stage_3_bl  (None, 3, 3, 2048)           0         ['convnext_xlarge_stage_3_bloc
#  ock_2_identity (Activation                                         k_2_layer_scale[0][0]']
#  )
#
#  tf.__operators__.add_71 (T  (None, 3, 3, 2048)           0         ['tf.__operators__.add_70[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_xlarge_stage_3_bloc
#                                                                     k_2_identity[0][0]']
#
#  global_max_pooling2d_1 (Gl  (None, 2048)                 0         ['tf.__operators__.add_71[0][0
#  obalMaxPooling2D)                                                  ]']
#
#  layer_normalization_1 (Lay  (None, 2048)                 4096      ['global_max_pooling2d_1[0][0]
#  erNormalization)                                                   ']
#
#  batch_normalization_3 (Bat  (None, 2048)                 8192      ['layer_normalization_1[0][0]'
#  chNormalization)                                                   ]
#
#  dense_6 (Dense)             (None, 256)                  524544    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 256)                  0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 2)                    514       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 348681218 (1.30 GB)
# Trainable params: 529154 (2.02 MB)
# Non-trainable params: 348152064 (1.30 GB)
# __________________________________________________________________________________________________

# %%
epochs=5000 #quante epoche prima che si stoppi del tutto  (lasciare alto)
ask_epoch=20 #ogni quanto viene chiesto di fermarsi
ask=LR_ASK(model, epochs,  ask_epoch, factor = 0.6) #factor misura quanto viene ridotto il learning rate se il validation loss è più alto del più bassso trovato fin'ora
callbacks=[ask]


history=model.fit(x=train_dataset,  #lascia così
                  epochs=epochs, 
                  verbose=1, 
                  callbacks=callbacks,  
                  validation_data=validation_dataset,
                  validation_steps=None,  
                  shuffle=False,  
                  initial_epoch=0)
# Out:
# Training will proceed until epoch 20 then you will be asked to
# enter H to halt training or enter an integer for how many more epochs to run then be asked again
# learning rate will be automatically adjusted during training (0, 255, 0)
# Epoch 1/5000
# 163/163 [==============================] - ETA: 0s - loss: 6.5855 - accuracy: 0.6077
#  validation loss of  4.7742 is  0.0000 % below lowest loss, saving weights from epoch 1   as best weights
# 163/163 [==============================] - 72s 319ms/step - loss: 6.5855 - accuracy: 0.6077 - val_loss: 4.7742 - val_accuracy: 0.7330
# Epoch 2/5000
# 163/163 [==============================] - ETA: 0s - loss: 4.2339 - accuracy: 0.6582
#  validation loss of  3.4120 is 28.5329 % below lowest loss, saving weights from epoch 2   as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 4.2339 - accuracy: 0.6582 - val_loss: 3.4120 - val_accuracy: 0.7300
# Epoch 3/5000
# 163/163 [==============================] - ETA: 0s - loss: 2.9975 - accuracy: 0.6521
#  validation loss of  2.4911 is 26.9883 % below lowest loss, saving weights from epoch 3   as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 2.9975 - accuracy: 0.6521 - val_loss: 2.4911 - val_accuracy: 0.7220
# Epoch 4/5000
# 163/163 [==============================] - ETA: 0s - loss: 2.1860 - accuracy: 0.6661
#  validation loss of  1.8183 is 27.0095 % below lowest loss, saving weights from epoch 4   as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 2.1860 - accuracy: 0.6661 - val_loss: 1.8183 - val_accuracy: 0.7530
# Epoch 5/5000
# 163/163 [==============================] - ETA: 0s - loss: 1.6460 - accuracy: 0.6834
#  validation loss of  1.3960 is 23.2245 % below lowest loss, saving weights from epoch 5   as best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 1.6460 - accuracy: 0.6834 - val_loss: 1.3960 - val_accuracy: 0.7480
# Epoch 6/5000
# 163/163 [==============================] - ETA: 0s - loss: 1.3099 - accuracy: 0.6911
#  validation loss of  1.1299 is 19.0629 % below lowest loss, saving weights from epoch 6   as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 1.3099 - accuracy: 0.6911 - val_loss: 1.1299 - val_accuracy: 0.7550
# Epoch 7/5000
# 163/163 [==============================] - ETA: 0s - loss: 1.0860 - accuracy: 0.6903
#  validation loss of  0.9578 is 15.2331 % below lowest loss, saving weights from epoch 7   as best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 1.0860 - accuracy: 0.6903 - val_loss: 0.9578 - val_accuracy: 0.7520
# Epoch 8/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.9511 - accuracy: 0.6942
#  validation loss of  0.8601 is 10.1926 % below lowest loss, saving weights from epoch 8   as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.9511 - accuracy: 0.6942 - val_loss: 0.8601 - val_accuracy: 0.7630
# Epoch 9/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.8704 - accuracy: 0.6813
#  validation loss of  0.7761 is  9.7729 % below lowest loss, saving weights from epoch 9   as best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.8704 - accuracy: 0.6813 - val_loss: 0.7761 - val_accuracy: 0.7560
# Epoch 10/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.8084 - accuracy: 0.6967
#  validation loss of  0.7362 is  5.1351 % below lowest loss, saving weights from epoch 10  as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.8084 - accuracy: 0.6967 - val_loss: 0.7362 - val_accuracy: 0.7560
# Epoch 11/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.7682 - accuracy: 0.6978
#  validation loss of  0.6992 is  5.0332 % below lowest loss, saving weights from epoch 11  as best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.7682 - accuracy: 0.6978 - val_loss: 0.6992 - val_accuracy: 0.7580
# Epoch 12/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.7492 - accuracy: 0.6878
#  validation loss of  0.6888 is  1.4805 % below lowest loss, saving weights from epoch 12  as best weights
# 163/163 [==============================] - 40s 242ms/step - loss: 0.7492 - accuracy: 0.6878 - val_loss: 0.6888 - val_accuracy: 0.7460
# Epoch 13/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.7271 - accuracy: 0.7038
#  validation loss of  0.7077 is  2.7453 % above lowest loss of  0.6888 keeping weights from epoch 12 as best weights
# learning rate was automatically adjusted from 0.001000 to 0.000600, model weights set to best weights
# 163/163 [==============================] - 39s 239ms/step - loss: 0.7271 - accuracy: 0.7038 - val_loss: 0.7077 - val_accuracy: 0.7510
# Epoch 14/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.7169 - accuracy: 0.7028
#  validation loss of  0.6451 is  6.3417 % below lowest loss, saving weights from epoch 14  as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.7169 - accuracy: 0.7028 - val_loss: 0.6451 - val_accuracy: 0.7770
# Epoch 15/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.7009 - accuracy: 0.7078
#  validation loss of  0.6335 is  1.8044 % below lowest loss, saving weights from epoch 15  as best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.7009 - accuracy: 0.7078 - val_loss: 0.6335 - val_accuracy: 0.7760
# Epoch 16/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.7105
#  validation loss of  0.6347 is  0.1857 % above lowest loss of  0.6335 keeping weights from epoch 15 as best weights
# learning rate was automatically adjusted from 0.000600 to 0.000360, model weights set to best weights
# 163/163 [==============================] - 39s 239ms/step - loss: 0.6865 - accuracy: 0.7105 - val_loss: 0.6347 - val_accuracy: 0.7600
# Epoch 17/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.7084
#  validation loss of  0.6303 is  0.5035 % below lowest loss, saving weights from epoch 17  as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.6841 - accuracy: 0.7084 - val_loss: 0.6303 - val_accuracy: 0.7540
# Epoch 18/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6710 - accuracy: 0.7159
#  validation loss of  0.6274 is  0.4694 % below lowest loss, saving weights from epoch 18  as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.6710 - accuracy: 0.7159 - val_loss: 0.6274 - val_accuracy: 0.7570
# Epoch 19/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6585 - accuracy: 0.7153
#  validation loss of  0.5961 is  4.9735 % below lowest loss, saving weights from epoch 19  as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.6585 - accuracy: 0.7153 - val_loss: 0.5961 - val_accuracy: 0.7830
# Epoch 20/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6594 - accuracy: 0.7157
#  validation loss of  0.6105 is  2.4094 % above lowest loss of  0.5961 keeping weights from epoch 19 as best weights
# learning rate was automatically adjusted from 0.000360 to 0.000216, model weights set to best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
#  30
# you entered 30 Training will continue to epoch 50
# 163/163 [==============================] - 1266s 8s/step - loss: 0.6594 - accuracy: 0.7157 - val_loss: 0.6105 - val_accuracy: 0.7690
# Epoch 21/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6510 - accuracy: 0.7090
#  validation loss of  0.5923 is  0.6461 % below lowest loss, saving weights from epoch 21  as best weights
# 163/163 [==============================] - 40s 242ms/step - loss: 0.6510 - accuracy: 0.7090 - val_loss: 0.5923 - val_accuracy: 0.7810
# Epoch 22/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6501 - accuracy: 0.7174
#  validation loss of  0.5968 is  0.7573 % above lowest loss of  0.5923 keeping weights from epoch 21 as best weights
# learning rate was automatically adjusted from 0.000216 to 0.000130, model weights set to best weights
# 163/163 [==============================] - 39s 239ms/step - loss: 0.6501 - accuracy: 0.7174 - val_loss: 0.5968 - val_accuracy: 0.7840
# Epoch 23/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6480 - accuracy: 0.7195
#  validation loss of  0.5927 is  0.0747 % above lowest loss of  0.5923 keeping weights from epoch 21 as best weights
# learning rate was automatically adjusted from 0.000130 to 0.000078, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6480 - accuracy: 0.7195 - val_loss: 0.5927 - val_accuracy: 0.7820
# Epoch 24/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6423 - accuracy: 0.7230
#  validation loss of  0.5892 is  0.5223 % below lowest loss, saving weights from epoch 24  as best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6423 - accuracy: 0.7230 - val_loss: 0.5892 - val_accuracy: 0.7890
# Epoch 25/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6323 - accuracy: 0.7311
#  validation loss of  0.5934 is  0.7114 % above lowest loss of  0.5892 keeping weights from epoch 24 as best weights
# learning rate was automatically adjusted from 0.000078 to 0.000047, model weights set to best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6323 - accuracy: 0.7311 - val_loss: 0.5934 - val_accuracy: 0.7790
# Epoch 26/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6309 - accuracy: 0.7364
#  validation loss of  0.5914 is  0.3664 % above lowest loss of  0.5892 keeping weights from epoch 24 as best weights
# learning rate was automatically adjusted from 0.000047 to 0.000028, model weights set to best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6309 - accuracy: 0.7364 - val_loss: 0.5914 - val_accuracy: 0.7830
# Epoch 27/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6335 - accuracy: 0.7318
#  validation loss of  0.5875 is  0.2976 % below lowest loss, saving weights from epoch 27  as best weights
# 163/163 [==============================] - 40s 244ms/step - loss: 0.6335 - accuracy: 0.7318 - val_loss: 0.5875 - val_accuracy: 0.7910
# Epoch 28/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6383 - accuracy: 0.7389
#  validation loss of  0.5860 is  0.2405 % below lowest loss, saving weights from epoch 28  as best weights
# 163/163 [==============================] - 40s 243ms/step - loss: 0.6383 - accuracy: 0.7389 - val_loss: 0.5860 - val_accuracy: 0.7860
# Epoch 29/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6373 - accuracy: 0.7288
#  validation loss of  0.5855 is  0.0991 % below lowest loss, saving weights from epoch 29  as best weights
# 163/163 [==============================] - 40s 243ms/step - loss: 0.6373 - accuracy: 0.7288 - val_loss: 0.5855 - val_accuracy: 0.7890
# Epoch 30/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.7307
#  validation loss of  0.5873 is  0.3147 % above lowest loss of  0.5855 keeping weights from epoch 29 as best weights
# learning rate was automatically adjusted from 0.000028 to 0.000017, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6304 - accuracy: 0.7307 - val_loss: 0.5873 - val_accuracy: 0.7810
# Epoch 31/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6324 - accuracy: 0.7324
#  validation loss of  0.5848 is  0.1066 % below lowest loss, saving weights from epoch 31  as best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6324 - accuracy: 0.7324 - val_loss: 0.5848 - val_accuracy: 0.7890
# Epoch 32/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.7366
#  validation loss of  0.5839 is  0.1510 % below lowest loss, saving weights from epoch 32  as best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6326 - accuracy: 0.7366 - val_loss: 0.5839 - val_accuracy: 0.7890
# Epoch 33/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6350 - accuracy: 0.7253
#  validation loss of  0.5848 is  0.1391 % above lowest loss of  0.5839 keeping weights from epoch 32 as best weights
# learning rate was automatically adjusted from 0.000017 to 0.000010, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6350 - accuracy: 0.7253 - val_loss: 0.5848 - val_accuracy: 0.7880
# Epoch 34/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6368 - accuracy: 0.7293
#  validation loss of  0.5848 is  0.1430 % above lowest loss of  0.5839 keeping weights from epoch 32 as best weights
# learning rate was automatically adjusted from 0.000010 to 0.000006, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6368 - accuracy: 0.7293 - val_loss: 0.5848 - val_accuracy: 0.7870
# Epoch 35/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.7293
#  validation loss of  0.5834 is  0.0895 % below lowest loss, saving weights from epoch 35  as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.6314 - accuracy: 0.7293 - val_loss: 0.5834 - val_accuracy: 0.7890
# Epoch 36/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6323 - accuracy: 0.7307
#  validation loss of  0.5842 is  0.1261 % above lowest loss of  0.5834 keeping weights from epoch 35 as best weights
# learning rate was automatically adjusted from 0.000006 to 0.000004, model weights set to best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6323 - accuracy: 0.7307 - val_loss: 0.5842 - val_accuracy: 0.7890
# Epoch 37/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6335 - accuracy: 0.7193
#  validation loss of  0.5820 is  0.2458 % below lowest loss, saving weights from epoch 37  as best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6335 - accuracy: 0.7193 - val_loss: 0.5820 - val_accuracy: 0.7880
# Epoch 38/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6365 - accuracy: 0.7232
#  validation loss of  0.5845 is  0.4286 % above lowest loss of  0.5820 keeping weights from epoch 37 as best weights
# learning rate was automatically adjusted from 0.000004 to 0.000002, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6365 - accuracy: 0.7232 - val_loss: 0.5845 - val_accuracy: 0.7870
# Epoch 39/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.7299
#  validation loss of  0.5828 is  0.1380 % above lowest loss of  0.5820 keeping weights from epoch 37 as best weights
# learning rate was automatically adjusted from 0.000002 to 0.000001, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6315 - accuracy: 0.7299 - val_loss: 0.5828 - val_accuracy: 0.7890
# Epoch 40/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.7220
#  validation loss of  0.5839 is  0.3208 % above lowest loss of  0.5820 keeping weights from epoch 37 as best weights
# learning rate was automatically adjusted from 0.000001 to 0.000001, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6372 - accuracy: 0.7220 - val_loss: 0.5839 - val_accuracy: 0.7880
# Epoch 41/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6365 - accuracy: 0.7216
#  validation loss of  0.5829 is  0.1584 % above lowest loss of  0.5820 keeping weights from epoch 37 as best weights
# learning rate was automatically adjusted from 0.000001 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6365 - accuracy: 0.7216 - val_loss: 0.5829 - val_accuracy: 0.7890
# Epoch 42/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6329 - accuracy: 0.7293
#  validation loss of  0.5823 is  0.0554 % above lowest loss of  0.5820 keeping weights from epoch 37 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 39s 240ms/step - loss: 0.6329 - accuracy: 0.7293 - val_loss: 0.5823 - val_accuracy: 0.7900
# Epoch 43/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.7288
#  validation loss of  0.5828 is  0.1374 % above lowest loss of  0.5820 keeping weights from epoch 37 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 39s 239ms/step - loss: 0.6315 - accuracy: 0.7288 - val_loss: 0.5828 - val_accuracy: 0.7900
# Epoch 44/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6306 - accuracy: 0.7284
#  validation loss of  0.5840 is  0.3494 % above lowest loss of  0.5820 keeping weights from epoch 37 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 39s 239ms/step - loss: 0.6306 - accuracy: 0.7284 - val_loss: 0.5840 - val_accuracy: 0.7870
# Epoch 45/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.7313
#  validation loss of  0.5817 is  0.0559 % below lowest loss, saving weights from epoch 45  as best weights
# 163/163 [==============================] - 39s 241ms/step - loss: 0.6345 - accuracy: 0.7313 - val_loss: 0.5817 - val_accuracy: 0.7860
# Epoch 46/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6328 - accuracy: 0.7282
#  validation loss of  0.5829 is  0.2122 % above lowest loss of  0.5817 keeping weights from epoch 45 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 40s 242ms/step - loss: 0.6328 - accuracy: 0.7282 - val_loss: 0.5829 - val_accuracy: 0.7890
# Epoch 47/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.7197
#  validation loss of  0.5826 is  0.1569 % above lowest loss of  0.5817 keeping weights from epoch 45 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 40s 243ms/step - loss: 0.6359 - accuracy: 0.7197 - val_loss: 0.5826 - val_accuracy: 0.7880
# Epoch 48/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6386 - accuracy: 0.7230
#  validation loss of  0.5824 is  0.1294 % above lowest loss of  0.5817 keeping weights from epoch 45 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6386 - accuracy: 0.7230 - val_loss: 0.5824 - val_accuracy: 0.7860
# Epoch 49/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6302 - accuracy: 0.7322
#  validation loss of  0.5826 is  0.1538 % above lowest loss of  0.5817 keeping weights from epoch 45 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
# 163/163 [==============================] - 39s 242ms/step - loss: 0.6302 - accuracy: 0.7322 - val_loss: 0.5826 - val_accuracy: 0.7890
# Epoch 50/5000
# 163/163 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.7324
#  validation loss of  0.5829 is  0.2050 % above lowest loss of  0.5817 keeping weights from epoch 45 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
